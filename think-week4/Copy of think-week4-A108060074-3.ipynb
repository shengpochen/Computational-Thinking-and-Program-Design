# %%
print("Hello Wrorld")
# Out:
# Hello Wrorld

# %%
print("你好嗎")
# Out:
# 你好嗎

# %%
print("Hello World")
print("你好嗎")
# Out:
# Hello World
# 你好嗎

# %% [markdown]
# 哈囉 好嗎

# %% [markdown]
# 嗨~我是陳昇鉑
